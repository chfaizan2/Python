# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x= np.array([1,2,3,4])
y= np.array([5,6,7,8])
plt.plot(x,y)
plt.show()

# %%
x1= np.array([1,5])
y1= np.array([4,10])
plt.plot(x1,y1,'o')
plt.show()

# %%
y= np.array([1,2,9,8,3,4,7,6,5,10])
plt.plot(y)
plt.show()
